# %% [markdown]
# <a href="https://colab.research.google.com/github/SurekhaBerlin/Kaggle/blob/main/Transportation_%26_Logistics_Analysis_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np

# %%
# Use read_excel to load an Excel file
df = pd.read_excel('/content/Transportation & Logistics Tracking Dataset.xlsx')

# %%
df.shape
# Out:
# (3585, 28)
